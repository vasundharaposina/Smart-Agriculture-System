# %% [markdown]
# <a href="https://colab.research.google.com/github/haripatel07/Smart_Agriculture_System/blob/main/Irrigation_schedule.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the csv
dataframe = pd.read_csv("Irrigation Scheduling.csv")

# %%
#Displaying top 5 rows
dataframe.head()
# Out:
#    id  temperature  pressure  altitude  soilmoisture  note  status     class  \
# 0   1        29.10   9984.53    -12.21           377     0       0  Very Dry
# 1   2        29.08   9984.36    -12.22           379     0       0  Very Dry
# 2   3        29.06   9984.56    -12.20           376     0       0  Very Dry
# 3   4        29.05   9984.39    -12.22           377     0       0  Very Dry
# 4   5        29.03   9984.42    -12.21           379     0       0  Very Dry
#
#          date      time
# 0  08/10/2022  22:06:24
# 1  08/10/2022  22:06:24
# 2  08/10/2022  22:06:24
# 3  08/10/2022  22:06:24
# 4  08/10/2022  22:06:24

# %%
#Displaying bottom 5 rows
dataframe.tail()
# Out:
#         id  temperature  pressure  altitude  soilmoisture  note  status class  \
# 4683  4684        29.34   9921.75    -17.49           327     1       0   Dry
# 4684  4685        29.31   9921.45    -17.52           328     1       0   Dry
# 4685  4686        29.29   9921.48    -17.51           328     1       0   Dry
# 4686  4687        29.26   9921.51    -17.51           327     1       0   Dry
# 4687  4688        29.28   9922.20    -17.45           323     1       0   Dry
#
#             date      time
# 4683  08/10/2022  22:06:24
# 4684  08/10/2022  22:06:24
# 4685  08/10/2022  22:06:24
# 4686  08/10/2022  22:06:24
# 4687  08/10/2022  22:06:24

# %%
#Columns
dataframe.columns
# Out:
# Index(['id', 'temperature', 'pressure', 'altitude', 'soilmoisture', 'note',
#        'status', 'class', 'date', 'time'],
#       dtype='object')

# %%
#Displaying class
dataframe['class']
# Out:
# 0       Very Dry
# 1       Very Dry
# 2       Very Dry
# 3       Very Dry
# 4       Very Dry
#           ...
# 4683         Dry
# 4684         Dry
# 4685         Dry
# 4686         Dry
# 4687         Dry
# Name: class, Length: 4688, dtype: object

# %%
#Checking the dimensions of the dataframe
dataframe.shape
# Out:
# (4688, 10)

# %%
#Describing data
dataframe.describe()
# Out:
#                 id  temperature      pressure     altitude  soilmoisture  \
# count  4688.000000  4688.000000   4688.000000  4682.000000   4688.000000
# mean   2344.500000    29.599089   9963.153215   -14.291506    243.692406
# std    1353.453361     5.842685   1383.602527     2.649815     76.176855
# min       1.000000    27.970000  -2120.400000   -17.610000   -243.000000
# 25%    1172.750000    28.630000   9935.255000   -16.340000    171.000000
# 50%    2344.500000    29.180000   9969.535000   -13.470000    233.000000
# 75%    3516.250000    29.990000   9975.700000   -12.950000    326.000000
# max    4688.000000   178.700000  99931.100000   116.700000    480.000000
#
#               note       status
# count  4688.000000  4688.000000
# mean      1.878413     0.703712
# std       1.152977     0.456668
# min       0.000000     0.000000
# 25%       1.000000     0.000000
# 50%       2.000000     1.000000
# 75%       3.000000     1.000000
# max       3.000000     1.000000

# %%
#Info of dataframe
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4688 entries, 0 to 4687
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            4688 non-null   int64
#  1   temperature   4688 non-null   float64
#  2   pressure      4688 non-null   float64
#  3   altitude      4682 non-null   float64
#  4   soilmoisture  4688 non-null   int64
#  5   note          4688 non-null   int64
#  6   status        4688 non-null   int64
#  7   class         4688 non-null   object
#  8   date          4688 non-null   object
#  9   time          4688 non-null   object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 366.4+ KB

# %%
#Checking for unique values
dataframe.nunique()
# Out:
# id              4688
# temperature      426
# pressure        2593
# altitude         555
# soilmoisture     262
# note               4
# status             2
# class              4
# date               1
# time               1
# dtype: int64

# %%
# Define the sensor range
min_value = -243
max_value = 480

dataframe['soilmoisture'] = 100 - ((dataframe['soilmoisture'] - min_value) / (max_value - min_value)) * 100
dataframe['soilmoisture'] = dataframe['soilmoisture'].clip(0, 100)

# %%
#Dropping unnecessary columns: Here id, date and time
modified_df = dataframe.drop(columns = {'id', 'date', 'time'})
modified_df.head()
# Out:
#    temperature  pressure  altitude  soilmoisture  note  status     class
# 0        29.10   9984.53    -12.21     54.529211     0       0  Very Dry
# 1        29.08   9984.36    -12.22     54.490950     0       0  Very Dry
# 2        29.06   9984.56    -12.20     54.548341     0       0  Very Dry
# 3        29.05   9984.39    -12.22     54.529211     0       0  Very Dry
# 4        29.03   9984.42    -12.21     54.490950     0       0  Very Dry

# %%
#Checking for null values
modified_df.isnull().sum()
# Out:
# temperature     0
# pressure        0
# altitude        6
# soilmoisture    0
# note            0
# status          0
# class           0
# dtype: int64

# %%
#Filling the null values in 'altitude' column
modified_df['altitude'] = modified_df['altitude'].fillna(modified_df['altitude'].mean())
modified_df.isnull().sum()
# Out:
# temperature     0
# pressure        0
# altitude        0
# soilmoisture    0
# note            0
# status          0
# class           0
# dtype: int64

# %%
#Checking count of each class
modified_df['class'].value_counts()
# Out:
# class
# Very Wet    1842
# Wet         1457
# Very Dry    1023
# Dry          366
# Name: count, dtype: int64

# %%
#Visualizing the class column
sns.countplot(x = 'class', data = modified_df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
#Pie plot
plt.pie(modified_df['class'].value_counts(), labels = modified_df['class'].value_counts().index)
plt.show()

# %%
#Here we will use label encoding, since there is a natural ordinal order
from sklearn.preprocessing import OrdinalEncoder
# Define the correct order of moisture levels
custom_order = [["Very Dry", "Dry", "Wet", "Very Wet"]]

# Initialize OrdinalEncoder with the predefined order
oe = OrdinalEncoder(categories=custom_order)
modified_df['class'] = oe.fit_transform(modified_df[['class']])
modified_df.head()
# Out:
#    temperature  pressure  altitude  soilmoisture  note  status  class
# 0        29.10   9984.53    -12.21     54.529211     0       0    0.0
# 1        29.08   9984.36    -12.22     54.490950     0       0    0.0
# 2        29.06   9984.56    -12.20     54.548341     0       0    0.0
# 3        29.05   9984.39    -12.22     54.529211     0       0    0.0
# 4        29.03   9984.42    -12.21     54.490950     0       0    0.0

# %%
modified_df['class'].value_counts()
# Out:
# class
# 3.0    1842
# 2.0    1457
# 0.0    1023
# 1.0     366
# Name: count, dtype: int64

# %% [markdown]
# # Checking for **correlations**

# %%
correlations = modified_df.corr()   #Leaving date and time
correlations
# Out:
#               temperature  pressure  altitude  soilmoisture      note  \
# temperature      1.000000  0.069229  0.286981      0.139279  0.034205
# pressure         0.069229  1.000000  0.697150      0.054813 -0.007703
# altitude         0.286981  0.697150  1.000000      0.133952  0.076151
# soilmoisture     0.139279  0.054813  0.133952      1.000000  0.969905
# note             0.034205 -0.007703  0.076151      0.969905  1.000000
# status           0.028588  0.003589  0.087718      0.894602  0.908939
# class            0.034205 -0.007703  0.076151      0.969905  1.000000
#
#                 status     class
# temperature   0.028588  0.034205
# pressure      0.003589 -0.007703
# altitude      0.087718  0.076151
# soilmoisture  0.894602  0.969905
# note          0.908939  1.000000
# status        1.000000  0.908939
# class         0.908939  1.000000

# %%
#Visualize the correlation of above data using heatmap
sns.heatmap(correlations, annot=True,fmt='.0%')
# Out:
# <Axes: >

# %% [markdown]
# # MODELS

# %%
#Dividing the data into X and y
#Here label will be the class
X = modified_df.iloc[:, :4].values  #Independent dataset
Y = modified_df.iloc[:, 6].values    #Dependent dataset
print(X)
print(Y)
# Out:
# [[  29.1        9984.53        -12.21         54.52921112]
#  [  29.08       9984.36        -12.22         54.49095038]
#  [  29.06       9984.56        -12.2          54.54834149]
#  ...
#  [  29.29       9921.48        -17.51         55.46659933]
#  [  29.26       9921.51        -17.51         55.4857297 ]
#  [  29.28       9922.2         -17.45         55.56225119]]
# [0. 0. 0. ... 1. 1. 1.]

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X, Y = smote.fit_resample(X, Y)

# %%
#Splitting dataset into 80% training and 20% testing
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state = 42)

# %%
#Scaling the data using Standard Scaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import cross_val_score

lr_classifier = LogisticRegression(C = 0.01, random_state = 42,class_weight='balanced', max_iter=1000)
lr_classifier.fit(X_train, Y_train)
y_pred_lr = lr_classifier.predict(X_test)
accuracy_lr = accuracy_score(Y_test, y_pred_lr)
print("Accuracy:", accuracy_lr)
# Out:
# Accuracy: 0.856625961103573

# %%
#Confusion Matrix
cm_lr = confusion_matrix(Y_test, y_pred_lr)
print(cm_lr)
# Out:
# [[485 111   0   0]
#  [151 363  19   0]
#  [  0   0 500  36]
#  [  0   0   0 546]]

# %%
#Classification report
from sklearn.metrics import classification_report
print(classification_report(Y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.81      0.79       596
#          1.0       0.77      0.68      0.72       533
#          2.0       0.96      0.93      0.95       536
#          3.0       0.94      1.00      0.97       546
#
#     accuracy                           0.86      2211
#    macro avg       0.86      0.86      0.86      2211
# weighted avg       0.86      0.86      0.85      2211

# %%
lr_cv_scores = cross_val_score(lr_classifier, sc.transform(X), Y, cv=5)
print(f"5-Fold CV Accuracy: {lr_cv_scores.mean():.4f} (+/- {lr_cv_scores.std() * 2:.4f})")
# Out:
# 5-Fold CV Accuracy: 0.8267 (+/- 0.1383)

# %%
#Fitting the Gaussian Naive Bayes Classifier model on X and Y
from sklearn.naive_bayes import GaussianNB

nb_classifier = GaussianNB()
nb_classifier.fit(X_train, Y_train)
y_pred_nb = nb_classifier.predict(X_test)
accuracy_nb = accuracy_score(Y_test, y_pred_nb)
print("Accuracy:", accuracy_nb)
# Out:
# Accuracy: 0.921302578018996

# %%
#Confusion Matrix
cm_nb = confusion_matrix(Y_test, y_pred_nb)
print(cm_nb)
# Out:
# [[468 128   0   0]
#  [ 27 493  13   0]
#  [  0   0 535   1]
#  [  0   0   5 541]]

# %%
#Classification Report
print(classification_report(Y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.79      0.86       596
#          1.0       0.79      0.92      0.85       533
#          2.0       0.97      1.00      0.98       536
#          3.0       1.00      0.99      0.99       546
#
#     accuracy                           0.92      2211
#    macro avg       0.93      0.92      0.92      2211
# weighted avg       0.93      0.92      0.92      2211

# %%
# 5-fold Cross-Validation
nb_cv_scores = cross_val_score(nb_classifier, sc.transform(X), Y, cv=5)
print(f"5-Fold CV Accuracy: {nb_cv_scores.mean():.4f} (+/- {nb_cv_scores.std() * 2:.4f})")
# Out:
# 5-Fold CV Accuracy: 0.9059 (+/- 0.1087)

# %%
#SVM
from sklearn.svm import SVC

svm_classifier = SVC(kernel = 'rbf', C = 0.1, random_state = 42)
svm_classifier.fit(X_train, Y_train)
y_pred_svm = svm_classifier.predict(X_test)
accuracy_svm = accuracy_score(Y_test, y_pred_svm)
print("Accuracy:", accuracy_svm)
# Out:
# Accuracy: 0.9443690637720489

# %%
#Confusion Matrix
cm_svm = confusion_matrix(Y_test, y_pred_svm)
print(cm_svm)
# Out:
# [[495 101   0   0]
#  [  1 514  18   0]
#  [  0   0 535   1]
#  [  0   0   2 544]]

# %%
#Classification Report
print(classification_report(Y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.83      0.91       596
#          1.0       0.84      0.96      0.90       533
#          2.0       0.96      1.00      0.98       536
#          3.0       1.00      1.00      1.00       546
#
#     accuracy                           0.94      2211
#    macro avg       0.95      0.95      0.95      2211
# weighted avg       0.95      0.94      0.94      2211

# %%
# 5-fold Cross-Validation
svm_cv_scores = cross_val_score(svm_classifier, sc.transform(X), Y, cv=5)
print(f"5-Fold CV Accuracy: {svm_cv_scores.mean():.4f} (+/- {svm_cv_scores.std() * 2:.4f})")
# Out:
# 5-Fold CV Accuracy: 0.8994 (+/- 0.1047)

# %%
#Plotting the different amongst the models
models = ['Logistic Regression', 'Naive Bayes', 'SVM']
accuracy = [accuracy_lr, accuracy_nb, accuracy_svm]

plt.bar(models, accuracy)
plt.title("Model Accuracy Comparison")
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.show()

# %%
#Check if the models are overfitting are not
y_train_pred_lr = lr_classifier.predict(X_train)
lr_train_acc = accuracy_score(Y_train, y_train_pred_lr)
print("Logistic Regression Training Accuracy:", accuracy_score(Y_train, y_train_pred_lr))
print("Logistic Regression Test Accuracy:", accuracy_lr)

y_train_pred_nb = nb_classifier.predict(X_train)
nb_train_acc = accuracy_score(Y_train, y_train_pred_nb)
print("Naive Bayes Training Accuracy:", accuracy_score(Y_train, y_train_pred_nb))
print("Naive Bayes Test Accuracy:", accuracy_nb)

y_train_pred_svm = svm_classifier.predict(X_train)
svm_train_acc = accuracy_score(Y_train, y_train_pred_svm)
print("SVM Training Accuracy:", accuracy_score(Y_train, y_train_pred_svm))
print("SVM Test Accuracy:", accuracy_svm)
# Out:
# Logistic Regression Training Accuracy: 0.8566996315687415
# Logistic Regression Test Accuracy: 0.856625961103573
# Naive Bayes Training Accuracy: 0.92398681403917
# Naive Bayes Test Accuracy: 0.921302578018996
# SVM Training Accuracy: 0.9503587356990498
# SVM Test Accuracy: 0.9443690637720489

# %%
# Visualize model comparison
plt.figure(figsize=(8, 6))
model_names = ["Logistic Regression", "Naive Bayes", "SVM"]
train_accs = [lr_train_acc, nb_train_acc, svm_train_acc]
test_accs = [accuracy_lr, accuracy_nb, accuracy_svm]
x = np.arange(len(model_names))
width = 0.35

plt.bar(x - width/2, train_accs, width, label='Train Accuracy', color='skyblue')
plt.bar(x + width/2, test_accs, width, label='Test Accuracy', color='lightcoral')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Model Performance Comparison')
plt.xticks(x, model_names, rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import joblib
joblib.dump([lr_classifier, sc], "irrigation_model.pkl")
# Out:
# ['irrigation_model.pkl']

# %%
model, scaler = joblib.load("irrigation_model.pkl")
input = np.array([27, 1012, 2.25, 90])
input_scale = scaler.transform(input.reshape(1, -1))
prediction = model.predict(input_scale)
print(prediction[0])
# Out:
# 3.0

# %%
test_inputs = np.array([[27, 1012, 2, 100], [30, 1015, 5, 50], [25, 1008, 0, 0]])  # Various moisture levels
input_scale = scaler.transform(test_inputs)
predictions = model.predict(input_scale)
print(predictions)
# Out:
# [3. 0. 0.]
